# %%
#### importantando as bibliotecas 

import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
##### carregando o arquivo #####
##### e inserir em um dataframe #####

path = 'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\'
file = 'vendas_2.xlsx'

##########################

### colocando o arquivo em um dataframe 

df = pd.read_excel(path + file )

######## visualizando o arquivo 

df.head()

df.sort_values('ValorVenda')
# Out:
#       ID-Produto           Produto         Categoria     Segmento Fabricante  \
# 433  SKU-0000434        Ventilador   Eletroportáteis    Doméstico       Arno
# 222  SKU-0000223             Grill  Eletrodomésticos    Doméstico     Consul
# 249  SKU-0000250         Aspirador   Eletroportáteis    Doméstico   Britânia
# 213  SKU-0000214        Fritadeira   Eletroportáteis    Doméstico       Arno
# 251  SKU-0000252         Aspirador   Eletroportáteis    Doméstico   Britânia
# ..           ...               ...               ...          ...        ...
# 176  SKU-0000177  Samsung Galaxy 8         Celulares  Corporativo    Samsung
# 150  SKU-0000151  Samsung Galaxy 8         Celulares  Corporativo    Samsung
# 147  SKU-0000148  Samsung Galaxy 8         Celulares  Corporativo    Samsung
# 157  SKU-0000158  Samsung Galaxy 8         Celulares  Corporativo    Samsung
# 154  SKU-0000155  Samsung Galaxy 8         Celulares  Corporativo    Samsung
#
# ...

# %%
#### descobrir a forma do dataframe 

### comando retorna as linhas e colunas 

df.shape

### df.describe()
df.info()
### df.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID-Produto   457 non-null    object
#  1   Produto      457 non-null    object
#  2   Categoria    457 non-null    object
#  3   Segmento     457 non-null    object
#  4   Fabricante   457 non-null    object
#  5   Loja         457 non-null    object
#  6   Cidade       457 non-null    object
#  7   Estado       457 non-null    object
#  8   Vendedor     457 non-null    object
#  9   ID-Vendedor  457 non-null    int64
#  10  Data Venda   457 non-null    datetime64[ns]
#  11  ValorVenda   457 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9)
# memory usage: 43.0+ KB

# %% [markdown]
# #CRIANDO UM GRAFICO DE COLUNAS

# %%
graficos = sns.barplot(x='Categoria',y='ValorVenda',data=df,ci = None)
### grafico 
graficos.bar_label(graficos.containers[0])
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_23968\1182968947.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   graficos = sns.barplot(x='Categoria',y='ValorVenda',data=df,ci = None)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#### grafico do produto 

graficos = sns.barplot(x='ValorVenda',y='Produto',data=df,ci = None)
### grafico 
graficos.bar_label(graficos.containers[0])
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_23968\717472557.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   graficos = sns.barplot(x='ValorVenda',y='Produto',data=df,ci = None)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
graficos = sns.barplot(x='Estado',y='ValorVenda',data=df,ci = None)
### grafico 
graficos.bar_label(graficos.containers[0])
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_23968\4143421988.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   graficos = sns.barplot(x='Estado',y='ValorVenda',data=df,ci = None)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
graficos = sns.barplot(x='ValorVenda',y='Segmento',data=df,ci = None)
### grafico 
graficos.bar_label(graficos.containers[0])
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_23968\39194230.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   graficos = sns.barplot(x='ValorVenda',y='Segmento',data=df,ci = None)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
base = df[['Data Venda','ValorVenda']].sort_values('Data Venda')

base = base.groupby('Data Venda').sum()

x = base ['Data Venda']
y = base ['ValorVenda']

plt.plot(x=base.index,y =base['ValorVenda'])

# %%
base = df[['Data Venda','ValorVenda']].sort_values('Data Venda')

base = base.groupby('Data Venda').sum()

x = base ['Data Venda']
y = base ['ValorVenda']

plt.plot(x=base.index,y =base['ValorVenda'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data Venda'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\FIC\Documents\Eder do Nascimento Bernardo\Aula12_2.ipynb Cell 10 line 5
# ...

# %%
#### grafico do produto 

graficos = sns.barplot(x='ValorVenda',y='Produto',data=df,ci = None)
### grafico 
graficos.bar_label(graficos.containers[0])
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_23968\717472557.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   graficos = sns.barplot(x='ValorVenda',y='Produto',data=df,ci = None)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
base = df[['Data Venda','ValorVenda']].sort_values('Data Venda')

base = base.groupby('Data Venda').sum()

#x = base ['Data Venda']
#y = base ['ValorVenda']

## plt.plot(x=base.index,y= base['ValorVenda'])

# %%
x = base.index
y = base ['ValorVenda']

plt.plot(x,y)
